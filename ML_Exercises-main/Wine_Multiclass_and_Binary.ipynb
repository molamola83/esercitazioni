# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/esercizi/winequality.csv
# Out:
# --2022-04-14 13:33:03--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/esercizi/winequality.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.149.158
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.149.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100951 (99K) [text/csv]
# Saving to: ‘winequality.csv’
#
# winequality.csv     100%[===================>]  98.58K   562KB/s    in 0.2s
#
# 2022-04-14 13:33:04 (562 KB/s) - ‘winequality.csv’ saved [100951/100951]

# %%
df= pd.read_csv('winequality.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# number of rows & columns in the dataset
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# #Is the problem balanced?

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# #Null values

# %%
import missingno as msno

# %%
msno.bar(df,figsize=(10,5),fontsize=12)

# %%
sns.catplot(x="quality", kind="count", palette="ch:.25", data=df);

# %%
sns.countplot(x='quality', data=df) #same graph but different style

# %%
sns.countplot(y="quality", data=df, palette="rocket")

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
from pandas.plotting import andrews_curves, parallel_coordinates

fig, axes = plt.subplots(2,1,figsize=(16,8))

andrews_curves(df,'quality', samples=50, linewidth=0.5, ax=axes[0])
axes[0].set_xticks([])
parallel_coordinates(df,'quality', linewidth=0.5, ax=axes[1],axvlines_kwds={'linewidth': 0.5, 'color': 'black', 'alpha':0.5})
axes[1].set_xticks([])
axes[1].margins(0.05)

# %%
import plotly.express as px

# %%
fig = px.parallel_coordinates(df, color="quality",
                              labels=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density','pH', 'sulphates', 'alcohol'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cc64061e-5cca-4ab8-97ce-6a6df697bfb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc64061e-5cca-4ab8-97ce-6a6df697bfb8")) {                    Plotly.newPlot(                        "cc64061e-5cca-4ab8-97ce-6a6df697bfb8",                        [{"dimensions":[{"label":"fixed acidity","values":[7.4,7.8,7.8,11.2,7.4,7.4,7.9,7.3,7.8,7.5,6.7,7.5,5.6,7.8,8.9,8.9,8.5,8.1,7.4,7.9,8.9,7.6,7.9,8.5,6.9,6.3,7.6,7.9,7.1,7.8,6.7,6.9,8.3,6.9,5.2,7.8,7.8,8.1,5.7,7.3,7.3,8.8,7.5,8.1,6.8,4.6,7.7,8.7,6.4,5.6,8.8,6.6,6.6,8.6,7.6,7.7,10.2,7.5,7.8,7.3,8.8,7.7,7.5,7.0,7.2,7.2,7.5,6.6,9.3,8.0,7.7,7.7,7.7,8.3,9.7,8.8,8.8,6.8,6.7,8.3,6.2,7.8,7.4,7.3,6.3,6.9,8.6,7.7,9.3,7.0,7.9,8.6,8.6,7.7,5.0,4.7,6.8,7.0,7.6,8.1,8.3,7.8,8.1,8.1,7.2,8.1,7.8,6.2,8.0,8.1,7.8,8.4,8.4,10.1,7.8,9.4,8.3,7.8,8.8,7.0,7.3,8.8,7.3,8.0,7.8,9.0,8.2,8.1,8.0,6.1,8.0,5.6,5.6,6.6,7.9,8.4,8.3,7.2,7.8,7.8,8.4,8.3,5.2,6.3,5.2,8.1,5.8,7.6,6.9,8.2,7.3,9.2,7.5,7.5,7.1,7.1,7.1,7.1,7.1,6.8,7.6,7.6,7.8,7.4,7.3,7.8,6.8,7.3,6.8,7.5,7.9,8.0,8.0,7.4,7.3,6.9,7.3,7.5,7.0,8.8
,0.58,9.5],[6.4,0.4,0.23,0.066,5.0,12.0,0.9958,3.34,0.56,9.2],[5.6,0.31,0.37,0.074,12.0,96.0,0.9954,3.32,0.58,9.2],[8.8,0.66,0.26,0.074,4.0,23.0,0.9971,3.15,0.74,9.2],[6.6,0.52,0.04,0.069,8.0,15.0,0.9956,3.4,0.63,9.4],[6.6,0.5,0.04,0.068,6.0,14.0,0.9955,3.39,0.64,9.4],[8.6,0.38,0.36,0.081,30.0,119.0,0.997,3.2,0.56,9.4],[7.6,0.51,0.15,0.11,33.0,73.0,0.9955,3.17,0.63,10.2],[7.7,0.62,0.04,0.084,25.0,45.0,0.9978,3.34,0.53,9.5],[10.2,0.42,0.57,0.07,4.0,10.0,0.9971,3.04,0.63,9.6],[7.5,0.63,0.12,0.111,50.0,110.0,0.9983,3.26,0.77,9.4],[7.8,0.59,0.18,0.076,17.0,54.0,0.9975,3.43,0.59,10.0],[7.3,0.39,0.31,0.074,9.0,46.0,0.9962,3.41,0.54,9.4],[8.8,0.4,0.4,0.079,19.0,52.0,0.998,3.44,0.64,9.2],[7.7,0.69,0.49,0.115,20.0,112.0,0.9968,3.21,0.71,9.3],[7.5,0.52,0.16,0.085,12.0,35.0,0.9968,3.38,0.62,9.5],[7.0,0.735,0.05,0.081,13.0,54.0,0.9966,3.39,0.57, ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True)

# %%
corr = df.corr()
target_corr = corr['quality'].abs().sort_values(ascending=False)

# %%
target_corr = target_corr[1:]

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=target_corr.index, y=target_corr)
plt.xticks(rotation=90, fontsize=12)
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.subplot(2,2,1)
sns.violinplot(x='quality', y='alcohol', data=df)
plt.subplot(2,2,2)
sns.violinplot(x='quality', y='sulphates', data=df)
plt.subplot(2,2,3)
sns.violinplot(x='quality', y='citric acid', data=df)
plt.subplot(2,2,4)
sns.violinplot(x='quality', y='volatile acidity', data=df)

# %%
sns.pairplot(data=df, corner=True, diag_kind="hist")

# %%
sns.pairplot(df, hue="quality", height=4)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Separating features and target

# %%
X = df.drop(columns=['quality'],axis=1)
y = df['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %% [markdown]
# #Standardizzazione

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
sc = StandardScaler()
standardized_data = sc.fit_transform(X)
X_ = standardized_data

# %% [markdown]
# #Train/Test

# %%
X_train, X_test, y_train, y_test = train_test_split(X_,y,
                                                    test_size = 0.2,
                                                    random_state=667
                                                    )

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1599, 11) (1279, 11) (320, 11)

# %%
from sklearn.ensemble import RandomForestClassifier

train_scores, test_scores = [],[]
# define the tree depths to evaluate
values = [i for i in range(1, 21)]
# evaluate a decision tree for each depth
for i in values:
	# configure the model
	model = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_y_pred = model.predict(X_train)
	train_acc = accuracy_score(y_train, train_y_pred)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_y_pred = model.predict(X_test)
	test_acc = accuracy_score(y_test, test_y_pred)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs tree depth

plt.figure(figsize=(18,10))
plt.plot(values, train_scores, '-o', label='Train Accuracy')
plt.plot(values, test_scores, '-o', label='Test Accuracy')
plt.legend()
# Out:
# >1, train: 0.579, test: 0.578
# >2, train: 0.599, test: 0.597
# >3, train: 0.609, test: 0.597
# >4, train: 0.656, test: 0.603
# >5, train: 0.711, test: 0.622
# >6, train: 0.772, test: 0.625
# >7, train: 0.813, test: 0.625
# >8, train: 0.865, test: 0.662
# >9, train: 0.912, test: 0.647
# >10, train: 0.953, test: 0.659
# >11, train: 0.978, test: 0.678
# >12, train: 0.991, test: 0.691
# >13, train: 0.996, test: 0.691
# >14, train: 0.998, test: 0.669
# >15, train: 1.000, test: 0.659
# >16, train: 1.000, test: 0.688
# >17, train: 1.000, test: 0.675
# >18, train: 1.000, test: 0.691
# >19, train: 1.000, test: 0.688
# >20, train: 1.000, test: 0.691

# %% [markdown]
# #Training model

# %%
classifier = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=8)

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, random_state=667)

# %%
#Feature importance for Random Forest
features = X_.columns
importances = classifier.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(18,10))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
# Out:
# Text(0.5, 0, 'Relative Importance')

# %% [markdown]
# #Model Evaluation

# %%
# accuracy score on the test data
y_pred = classifier.predict(X_test)
test_data_accuracy = accuracy_score(y_test, y_pred)

print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.6625

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
labels = ["3","4","5","6","7","8"]
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00        12
#            5       0.73      0.81      0.77       135
#            6       0.60      0.69      0.64       129
#            7       0.62      0.35      0.45        37
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.66       320
#    macro avg       0.32      0.31      0.31       320
# weighted avg       0.62      0.66      0.64       320
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = ConfusionMatrixDisplay.from_estimator(classifier, 
                                      X_test, 
                                      y_test,
                                      cmap='Blues',
                                      display_labels=labels,
                                      xticks_rotation=45,
                                      )

# %% [markdown]
# #Creando due classi (binary problem)

# %%
df['quality binary']= df['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
sns.catplot(x="quality binary", kind="count", palette="ch:.25", data=df);
 #decisamente sbilanciato
# Out:
# '#decisamente sbilanciato'

# %%
df['quality'].value_counts().sort_values(ascending=True)
# Out:
# 3     10
# 8     18
# 4     53
# 7    199
# 6    638
# 5    681
# Name: quality, dtype: int64

# %%
df['quality binary']= df['quality'].apply(lambda y_value: 1 if y_value>=6 else 0)

# %%
sns.catplot(x="quality binary", kind="count", palette="ch:.25", data=df); #ora è più bilanciato

# %%
qualità = {0:'<6', 1:'>=6'} #mi salvo un dizionario con il significato di 0 ed 1 da poter richiamare quando voglio

# %%
qualità
# Out:
# {0: '<6', 1: '>=6'}

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'quality binary'],
#       dtype='object')

# %%
df1=df.drop(columns='quality')

# %%
df1.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality binary'],
#       dtype='object')

# %%
plt.figure(figsize=(18,10))

sns.heatmap(df1.corr(), fmt = '.1f', annot = True, cmap = 'Blues');

# %%
corr = df1.corr()
target_corr = corr['quality binary'].abs().sort_values(ascending=False)

# %%
target_corr = target_corr[1:]

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=target_corr.index, y=target_corr)
plt.xticks(rotation=90, fontsize=12)
plt.show()

# %% [markdown]
# ##features/target

# %%
X = df1.drop('quality binary',axis=1) #features
y=df1['quality binary'] #target

# %% [markdown]
# ##Standard.

# %%
sc = StandardScaler()
standardized_data = sc.fit_transform(X)
X_ = standardized_data
X_
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.96024611],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.58477711],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.58477711],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.54162988],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.20930812],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.54162988]])

# %%
y.value_counts()
# Out:
# 1    855
# 0    744
# Name: quality binary, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_, y, 
                                                    test_size=0.2,
                                                    random_state=667
                                                    )

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1599, 11) (1279, 11) (320, 11)

# %%
from sklearn.ensemble import RandomForestClassifier

train_scores, test_scores = [],[]
# define the tree depths to evaluate
values = [i for i in range(1, 21)]
# evaluate a decision tree for each depth
for i in values:
	# configure the model
	model = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=i)
	# fit model on the training dataset
	model.fit(X_train, y_train)
	# evaluate on the train dataset
	train_y_pred = model.predict(X_train)
	train_acc = accuracy_score(y_train, train_y_pred)
	train_scores.append(train_acc)
	# evaluate on the test dataset
	test_y_pred = model.predict(X_test)
	test_acc = accuracy_score(y_test, test_y_pred)
	test_scores.append(test_acc)
	# summarize progress
	print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs tree depth

plt.figure(figsize=(18,10))
plt.plot(values, train_scores, '-o', label='Train Accuracy')
plt.plot(values, test_scores, '-o', label='Test Accuracy')
plt.legend()
# Out:
# >1, train: 0.740, test: 0.700
# >2, train: 0.764, test: 0.734
# >3, train: 0.775, test: 0.744
# >4, train: 0.793, test: 0.766
# >5, train: 0.831, test: 0.756
# >6, train: 0.869, test: 0.769
# >7, train: 0.903, test: 0.766
# >8, train: 0.937, test: 0.778
# >9, train: 0.962, test: 0.781
# >10, train: 0.981, test: 0.803
# >11, train: 0.991, test: 0.797
# >12, train: 0.997, test: 0.809
# >13, train: 0.999, test: 0.806
# >14, train: 1.000, test: 0.791
# >15, train: 1.000, test: 0.812
# >16, train: 1.000, test: 0.800
# >17, train: 1.000, test: 0.806
# >18, train: 1.000, test: 0.816
# >19, train: 1.000, test: 0.809
# >20, train: 1.000, test: 0.809

# %%
classifier = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=10)

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=667)

# %%
#Feature importance for Random Forest
features = X.columns
importances = classifier.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(18,10))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
# Out:
# Text(0.5, 0, 'Relative Importance')

# %%
# accuracy score on the test data
y_pred = classifier.predict(X_test)
test_data_accuracy = accuracy_score(y_test,y_pred)

print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.803125

# %%
qualità
# Out:
# {0: '<6', 1: '>=6'}

# %%
labels = ['Bad Quality', 'Good Quality']

# %%
from sklearn.metrics import ConfusionMatrixDisplay

#labels = ['class1', 'class2']
cm = ConfusionMatrixDisplay.from_estimator(classifier, 
                                      X_test, 
                                      y_test,
                                      cmap='Blues',
                                      display_labels=labels,
                                      xticks_rotation=45,
                                      )
cm;

# %%
from sklearn.metrics import classification_report
#labels = ['class1', 'class2']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#  Bad Quality       0.81      0.76      0.78       150
# Good Quality       0.80      0.84      0.82       170
#
#     accuracy                           0.80       320
#    macro avg       0.80      0.80      0.80       320
# weighted avg       0.80      0.80      0.80       320

# %% [markdown]
# ##ROC Curves

# %%
# !pip install plot-metric --quiet

# %%
from plot_metric.functions import BinaryClassification
y_pred_proba = classifier.predict_proba(X_test)[::,1]

#labels = ['class1', 'class2']
bc = BinaryClassification(y_test, y_pred_proba, labels=labels)

# Figures
plt.figure(figsize=(10,10))
bc.plot_roc_curve();

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.8774901960784314

# %%
# Figures
plt.figure(figsize=(10,10))
bc.plot_precision_recall_curve();

# %%
input_data = (7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5)

# changing the input data to a numpy array
input_np = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_np.reshape(1,-1)

prediction = classifier.predict(input_data_reshaped)
print(prediction[0])

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# 0
# Bad Quality Wine

# %% [markdown]
# ##Features Selection

# %%
from sklearn.feature_selection import RFE #features selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

featu=[]
for i in range(2,len(X.columns)):
    rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=i)
    classifier = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=8)
    pipe = Pipeline([
                    ('scaler', StandardScaler()),
                    ('featureselection',rfe),
                    ('classifier',classifier)
                    ])
    pipe.fit(X_train,y_train)
    test_y_pred = pipe.predict(X_test)
    test_acc = accuracy_score(y_test, test_y_pred)
    y_pred_proba = pipe.predict_proba(X_test)[::,1]
    roc_auc = roc_auc_score(y_test,y_pred_proba)
    featu.append(roc_auc)
    # summarize progress
    print('feature selected %d, Acc.Test: %.3f, AUC: %.3f' % (i, test_acc, roc_auc ))

print('\n Best number of feature selection is: %d' % (np.argmax(featu) +2))
# Out:
# feature selected 2, Acc.Test: 0.747, AUC: 0.813
# feature selected 3, Acc.Test: 0.769, AUC: 0.848
# feature selected 4, Acc.Test: 0.784, AUC: 0.846
# feature selected 5, Acc.Test: 0.781, AUC: 0.854
# feature selected 6, Acc.Test: 0.775, AUC: 0.859
# feature selected 7, Acc.Test: 0.778, AUC: 0.860
# feature selected 8, Acc.Test: 0.784, AUC: 0.863
# feature selected 9, Acc.Test: 0.781, AUC: 0.862
# feature selected 10, Acc.Test: 0.772, AUC: 0.867
#
#  Best number of feature selection is: 10

# %%
# X = features not standardized
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.25,
                                                    random_state=667
                                                    )

# %%
standardize = StandardScaler()
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=10)
classifier = RandomForestClassifier(random_state=667, n_estimators=100,max_depth=10)

pipe = Pipeline([
                ('scaler', StandardScaler()),
                ('featureselection',rfe),
                ('classifier',classifier)
                ])
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('featureselection',
#                  RFE(estimator=DecisionTreeClassifier(),
#                      n_features_to_select=10)),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=10, random_state=667))])

# %%
input_data = [7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5]

prediction = pipe.predict([input_data])
print(prediction[0])

if (y_pred[0] == 0):
  print('Bad Quality Wine')
else:
  print('Good Quality Wine')

# %%
import joblib
joblib.dump(pipe,'pipe_wine.pkl')
# Out:
# ['pipe_wine.pkl']

# %%
uploaded_model = joblib.load('pipe_wine.pkl')

uploaded_model.predict([input_data])[0]
